# %% [markdown]
# # DSA Assignment 22

# %%
import urllib.request
from PIL import Image

# %% [raw]
# Question-1:
# Given a Binary Tree (Bt), convert it to a Doubly Linked List(DLL). The left and right pointers in nodes are to be used as previous and next pointers respectively in converted DLL. The order of nodes in DLL must be the same as in Inorder for the given Binary Tree. The first node of Inorder traversal (leftmost node in BT) must be the head node of the DLL.
# Example:

# %%
urllib.request.urlretrieve('https://file.notion.so/f/s/f9dda6ae-60b9-427b-990f-dc5b3117a5e3/Untitled.png?id=f5542efd-4d64-4904-9259-23aeb80f012b&table=block&spaceId=6fae2e0f-dedc-48e9-bc59-af2654c78209&expirationTimestamp=1688191200000&signature=zXLPWmtRuO898qAC_D25EJ13dhNGcOxKFIUkxmhIUpE&downloadName=Untitled.png',"gfg.png")
img_1 = Image.open("gfg.png")
img_1.show()
# Out:
# /usr/bin/xdg-open: 882: www-browser: not found
# /usr/bin/xdg-open: 882: links2: not found
# /usr/bin/xdg-open: 882: elinks: not found
# /usr/bin/xdg-open: 882: links: not found
# /usr/bin/xdg-open: 882: lynx: not found
# /usr/bin/xdg-open: 882: w3m: not found
# xdg-open: no method available for opening '/tmp/tmpwe06zq8x.PNG'

# %%
img = Image.open("gfg.png")
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=862x484>

# %%
class TreeNode:
    def __init__(self, val):
        self.val = val
        self.left = None
        self.right = None

def binaryTreeToDLL(root):
    if not root:
        return None

    global prev, head
    prev = None
    head = None

    def inorderTraversal(node):
        global prev, head
        if node:
            inorderTraversal(node.left)

            if prev:
                prev.right = node
                node.left = prev
            else:
                head = node

            prev = node

            inorderTraversal(node.right)

    inorderTraversal(root)

    head.left = prev
    prev.right = head

    return head

def printDLL(head):
    current = head
    while True:
        print(current.val, end=" ")
        current = current.right
        if current == head:
            break
    print()

root = TreeNode(10)
root.left = TreeNode(12)
root.right = TreeNode(15)
root.left.left = TreeNode(25)
root.left.right = TreeNode(30)
root.right.left = TreeNode(36)

dll_head = binaryTreeToDLL(root)

printDLL(dll_head)
# Out:
# 25 12 30 10 36 15

# %% [raw]
# Question-2
# A Given a binary tree, the task is to flip the binary tree towards the right direction that is clockwise. See the below examples to see the transformation.
# In the flip operation, the leftmost node becomes the root of the flipped tree and its parent becomes its right child and the right sibling becomes its left child and the same should be done for all left most nodes recursively.
# Example1:

# %%
urllib.request.urlretrieve('https://file.notion.so/f/s/a5f5bbbe-8607-4f17-9ab4-b31327ffa2d0/Untitled.png?id=bf2642e8-4284-4d78-9cf8-ea00a926b238&table=block&spaceId=6fae2e0f-dedc-48e9-bc59-af2654c78209&expirationTimestamp=1688198400000&signature=YASFn3sZxRj_9os1vqWn5GzwINxogIHLOi4uWlPGYTo&downloadName=Untitled.png',"question.png")
img_1 = Image.open("question.png")
img_1.show()
# Out:
# /usr/bin/xdg-open: 882: www-browser: not found
# /usr/bin/xdg-open: 882: links2: not found
# /usr/bin/xdg-open: 882: elinks: not found
# /usr/bin/xdg-open: 882: links: not found
# /usr/bin/xdg-open: 882: lynx: not found
# /usr/bin/xdg-open: 882: w3m: not found
# xdg-open: no method available for opening '/tmp/tmpy3nyp_wi.PNG'

# %%
img_1=Image.open("question.png")
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=862x484>

# %%
urllib.request.urlretrieve('https://file.notion.so/f/s/063636b4-9f35-4524-b6d9-c97e30cac510/Untitled.png?id=257a6e42-4876-4a44-ac0e-07f80a570f83&table=block&spaceId=6fae2e0f-dedc-48e9-bc59-af2654c78209&expirationTimestamp=1688198400000&signature=KBrSUKnY01W3hMUBEO_-9bg9_gs7vCd0cECgiKRz7nI&downloadName=Untitled.png',"question1.png")
img_2 = Image.open("question1.png")
img_2.show()
# Out:
# /usr/bin/xdg-open: 882: www-browser: not found
# /usr/bin/xdg-open: 882: links2: not found
# /usr/bin/xdg-open: 882: elinks: not found
# /usr/bin/xdg-open: 882: links: not found
# /usr/bin/xdg-open: 882: lynx: not found
# /usr/bin/xdg-open: 882: w3m: not found
# xdg-open: no method available for opening '/tmp/tmpv6r2kim2.PNG'

# %%
img_2 = Image.open("question1.png")
img_2
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=653x343>

# %%
class TreeNode:
    def __init__(self, val):
        self.val = val
        self.left = None
        self.right = None

def flipBinaryTree(root):
    if not root:
        return None

    if not root.left and not root.right:
        return root

    flipped_left = flipBinaryTree(root.left)
    flipped_right = flipBinaryTree(root.right)

    root.left = flipped_right
    root.right = flipped_left

    return root

def printTree(root):
    if not root:
        return
    print(root.val)
    printTree(root.left)
    printTree(root.right)

root = TreeNode(10)
root.left = TreeNode(12)
root.right = TreeNode(15)
root.left.left = TreeNode(25)
root.left.right = TreeNode(30)
root.right.left = TreeNode(36)

flipped_root = flipBinaryTree(root)

printTree(flipped_root)
# Out:
# 10
# 15
# 36
# 12
# 30
# 25

# %% [raw]
# Question-3:
#
# Given a binary tree, print all its root-to-leaf paths without using recursion. For example, consider the following Binary Tree.
#
# Input:
#
#         6
#      /    \
#     3      5
#   /   \     \
#  2     5     4
#      /   \
#     7     4
#
# Output:
#
# There are 4 leaves, hence 4 root to leaf paths -
#   6->3->2
#   6->3->5->7
#   6->3->5->4
#   6->5>4

# %%
class TreeNode:
    def __init__(self, val):
        self.val = val
        self.left = None
        self.right = None

def printRootToLeafPaths(root):
    if not root:
        return

    stack = [(root, str(root.val))]

    while stack:
        node, path = stack.pop()

        if not node.left and not node.right:
            print(path)
        
        if node.right:
            stack.append((node.right, path + '->' + str(node.right.val)))

        if node.left:
            stack.append((node.left, path + '->' + str(node.left.val)))

root = TreeNode(6)
root.left = TreeNode(3)
root.right = TreeNode(5)
root.left.left = TreeNode(2)
root.left.right = TreeNode(5)
root.right.right = TreeNode(4)
root.left.right.left = TreeNode(7)
root.left.right.right = TreeNode(4)

printRootToLeafPaths(root)
# Out:
# 6->3->2
# 6->3->5->7
# 6->3->5->4
# 6->5->4

# %% [raw]
# Question-4:
# Given Preorder, Inorder and Postorder traversals of some tree. Write a program to check if they all are of the same tree.
# Examples:
# Input :
#
#         Inorder -> 4 2 5 1 3
#         Preorder -> 1 2 4 5 3
#         Postorder -> 4 5 2 3 1
# Output :
# Yes
# Explanation :
# All of the above three traversals are of
# the same tree
#
#                            1
#                          /   \
#                         2     3
#                       /   \
#                      4     5
#
# Input :
#
#         Inorder -> 4 2 5 1 3
#         Preorder -> 1 5 4 2 3
#         Postorder -> 4 1 2 3 5
# Output :
#
# No
